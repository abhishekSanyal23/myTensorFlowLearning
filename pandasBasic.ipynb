# %% [markdown]
# # Pandas Basic

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/csvFiles/Traffic_Violations.csv')

# %%
#Fetch Columns
df.Gender
df['Gender']
# Out:
# 0         M
# 1         F
# 2         F
# 3         M
# 4         M
# 5         M
# 6         M
# 7         F
# 8         M
# 9         M
# 10        M
# 11        F
# 12        M
# 13        M
# 14        M
# 15        F
# 16        M
# 17        M
# 18        M
# 19        M
# 20        M
# 21        M
# 22        M
# 23        M
# 24        M
# 25        M
# 26        F
# 27        M
# 28        M
# 29        F
#          ..
# 161448    F
# 161449    M
# 161450    F
# 161451    M
# 161452    F
# 161453    M
# 161454    M
# 161455    M
# 161456    M
# 161457    M
# 161458    M
# 161459    M
# 161460    M
# 161461    M
# 161462    F
# 161463    F
# 161464    M
# 161465    M
# 161466    M
# 161467    F
# 161468    F
# 161469    M
# 161470    F
# 161471    M
# 161472    M
# 161473    F
# 161474    M
# 161475    M
# 161476    F
# 161477    M
# Name: Gender, Length: 161478, dtype: object

# %%
df[['Accident', 'Gender']]
# Out:
#        Accident Gender
# 0            No      M
# 1            No      F
# 2            No      F
# 3            No      M
# 4            No      M
# 5            No      M
# 6            No      M
# 7            No      F
# 8            No      M
# 9            No      M
# 10           No      M
# 11           No      F
# 12           No      M
# 13           No      M
# 14           No      M
# 15           No      F
# 16           No      M
# 17           No      M
# 18           No      M
# 19           No      M
# 20           No      M
# 21           No      M
# 22           No      M
# 23           No      M
# 24           No      M
# 25           No      M
# 26           No      F
# 27           No      M
# 28           No      M
# 29           No      F
# ...         ...    ...
# 161448       No      F
# 161449       No      M
# 161450       No      F
# 161451       No      M
# 161452       No      F
# 161453       No      M
# 161454       No      M
# 161455       No      M
# ...

# %%
df.Year.max()
# Out:
# 9999.0

# %%
df.Year.min()
# Out:
# 0.0

# %%
df.describe()
# Out:
#             Latitude      Longitude           Year
# count  151756.000000  151756.000000  160474.000000
# mean       39.083444     -77.112769    2006.008113
# std         0.066995       0.092739      77.035229
# min        38.502245     -77.732257       0.000000
# 25%        39.037356     -77.194695    2003.000000
# 50%        39.073192     -77.094773    2007.000000
# 75%        39.132820     -77.047679    2012.000000
# max        39.914737     -76.346121    9999.000000

# %%
df[df['Year'] == 2012]
# Out:
#        Date Of Stop Time Of Stop Agency  \
# 2        11/23/2016     14:16:00    MCP
# 15       11/23/2016     13:04:00    MCP
# 26       11/23/2016     16:08:00    MCP
# 31       11/23/2016     14:48:00    MCP
# 62       11/23/2016     10:02:00    MCP
# 114      11/23/2016     20:27:00    MCP
# 153      11/22/2016     22:58:00    MCP
# 195      11/23/2016     21:20:00    MCP
# 196      11/23/2016     21:49:00    MCP
# 249      11/22/2016     23:45:00    MCP
# 278      11/23/2016     16:08:00    MCP
# 313      11/23/2016     22:42:00    MCP
# 317      11/23/2016     14:16:00    MCP
# 320      11/23/2016     01:13:00    MCP
# 331      11/23/2016     08:45:00    MCP
# 343      11/23/2016     10:02:00    MCP
# 357      11/23/2016     20:23:00    MCP
# 358      11/23/2016     20:23:00    MCP
# 359      11/23/2016     20:23:00    MCP
# 383      11/23/2016     20:27:00    MCP
# 385      11/23/2016     22:15:00    MCP
# 386      11/23/2016     22:15:00    MCP
# ...

# %%
df[df['Year'] == 2012].as_matrix()
# Out:
# /home/abhishek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([['11/23/2016', '14:16:00', 'MCP', ..., 'MD', 'A - Marked Patrol',
#         '(39.1046833333333, -76.933665)'],
#        ['11/23/2016', '13:04:00', 'MCP', ..., 'MD', 'A - Marked Patrol',
#         '(39.1473333333333, -77.2154083333333)'],
#        ['11/23/2016', '16:08:00', 'MCP', ..., 'MD', 'A - Marked Patrol',
#         '(39.171, -77.20468)'],
#        ...,
#        ['11/23/2016', '02:10:00', 'MCP', ..., 'VA', 'A - Marked Patrol',
#         '(39.03086, -77.0480966666667)'],
#        ['11/23/2016', '02:10:00', 'MCP', ..., 'VA', 'A - Marked Patrol',
#         '(39.03086, -77.0480966666667)'],
#        ['10/18/2016', '16:30:00', 'MCP', ..., 'MD', 'A - Marked Patrol',
#         '(38.9902516666667, -77.0167883333333)']], dtype=object)

# %%
df[df['Year'] == 2012].values
# Out:
# array([['11/23/2016', '14:16:00', 'MCP', ..., 'MD', 'A - Marked Patrol',
#         '(39.1046833333333, -76.933665)'],
#        ['11/23/2016', '13:04:00', 'MCP', ..., 'MD', 'A - Marked Patrol',
#         '(39.1473333333333, -77.2154083333333)'],
#        ['11/23/2016', '16:08:00', 'MCP', ..., 'MD', 'A - Marked Patrol',
#         '(39.171, -77.20468)'],
#        ...,
#        ['11/23/2016', '02:10:00', 'MCP', ..., 'VA', 'A - Marked Patrol',
#         '(39.03086, -77.0480966666667)'],
#        ['11/23/2016', '02:10:00', 'MCP', ..., 'VA', 'A - Marked Patrol',
#         '(39.03086, -77.0480966666667)'],
#        ['10/18/2016', '16:30:00', 'MCP', ..., 'MD', 'A - Marked Patrol',
#         '(38.9902516666667, -77.0167883333333)']], dtype=object)
